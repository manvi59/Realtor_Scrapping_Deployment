# %%
# Parameters
location = "houston_tx"
final_url = "/type-single-family-home/dom-1/price-500000-900000"

# %%
import requests
import time
import sys
from bs4 import BeautifulSoup
import json
 
cookies = {
    '_cq_duid': '1.1744778181.6MobFmGeC2R1nUU7',
    'split': 'n',
    '__vst': '510a7abc-5631-4c8b-a9a5-54de51e58a8a',
    '__bot': 'false',
    '_lr_env_src_ats': 'false',
    'permutive-id': '36491759-b0ef-4036-bc03-7d07f765413e',
    's_ecid': 'MCMID%7C62206642167978879802294781651943730817',
    '_cc_id': 'f15316d1891455e0cdcc7f071e6be91a',
    '_gcl_au': '1.1.761638148.1744778188',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%22768f16ce-051a-44b9-986e-505d5a184422%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-03-16T04%3A36%3A27%22%7D',
    'pbjs-unifiedid_cst': 'VyxHLMwsHQ%3D%3D',
    '__gsas': 'ID=b761dbf92fed2797:T=1744778187:RT=1744778187:S=ALNI_MYyPr435-r92Lh6hgKWE7ir2wPpFg',
    '__split': '11',
    '_ga': 'GA1.1.122217795.1744778189',
    '_fbp': 'fb.1.1744778190942.615506763789365416',
    'ajs_anonymous_id': '484b625d-2e90-49a9-82ea-71509bf26df2',
    'kampyle_userid': '597b-3652-68fb-14df-8b6d-f4a2-9005-9eb6',
    'cto_bundle': 'OyMQ419RVHR2WTVsekpyUlYyaUt1RzBVN25kNWJ5eG45aU1kZ21lc3NIREpMTHVNcm4ybXA5Z0ZmMzF3YXZZaEVISyUyQlpoeE9rQlN3N2dsNVlWZmRwc2d6TjhucUExcSUyQjhwSHVqNExBVjdVZUU3eE5OdjRmRlc2SEZld3c2SFhpMVI0Slh0NmN6Ymh3MzlPN1kzJTJGeFZObEklMkJpQSUzRCUzRA',
    'G_ENABLED_IDPS': 'google',
    '__spdt': 'fec8a0e0243d44f7ac0a8810ea3a5617',
    '_pbjs_userid_consent_data': '3524755945110770',
    'spec-property-history': 'true',
    '_lr_sampling_rate': '100',
    'sbjs_migrations': '1418474375998%3D1',
    'sbjs_current_add': 'fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29',
    'sbjs_first_add': 'fd%3D2025-05-13%2015%3A38%3A57%7C%7C%7Cep%3Dhttps%3A%2F%2Fwww.realtor.com%2Frealestateagents%2FMarie-Crabb_San-Antonio_TX_1562457_770159571%7C%7C%7Crf%3D%28none%29',
    'sbjs_current': 'typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29',
    'sbjs_first': 'typ%3Dtypein%7C%7C%7Csrc%3D%28direct%29%7C%7C%7Cmdm%3D%28none%29%7C%7C%7Ccmp%3D%28none%29%7C%7C%7Ccnt%3D%28none%29%7C%7C%7Ctrm%3D%28none%29',
    'sbjs_udata': 'vst%3D1%7C%7C%7Cuip%3D%28none%29%7C%7C%7Cuag%3DMozilla%2F5.0%20%28Windows%20NT%2010.0%3B%20Win64%3B%20x64%29%20AppleWebKit%2F537.36%20%28KHTML%2C%20like%20Gecko%29%20Chrome%2F136.0.0.0%20Safari%2F537.36',
    'AWSALBTG': 'Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL',
    'AWSALBTGCORS': 'Gysy51HA+pJTrxIKFj2v3w0nCE/eoaQmJ7DSPj4suoUKY1CHB4l5GhwD4Qau/EW7RngdZBfgTbUsgutlOm0f96YiXJTcsrWR+T8lWoqugNfMSDTEbOwrgbTJv4zI4vgeWeD4ltJdQFCOglNyh0FuxME92j87R8+5+nrtZTwzAFAL',
    'AWSALB': 'PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY',
    'AWSALBCORS': 'PA4KsCC+ZE35rkHrZlFJmvdEFqqcwpfhPvIHyR8fvTkTuV8elUxXm3ZXx+OJ8h1qNL5Hsxp9M9bcRnTPQfhDhKnSOIaGtgnBBIXsSuTsBL6E4DClOUhJXGkw1ucY',
    'leadid_token-27789EFE-7A9A-DB70-BB9B-97D9B7057DBB-01836014-7527-FD48-9B7F-1A40A9705CFE': '86378343-6E72-C9A3-F38C-4FC85D4B9DDF',
    '_parsely_session': '{%22sid%22:25%2C%22surl%22:%22https://www.realtor.com/realestateandhomes-detail/127-Concord-St_Brooklyn_NY_11201_M94228-18638%22%2C%22sref%22:%22https://colab.research.google.com/%22%2C%22sts%22:1747135330658%2C%22slts%22:1747130960659}',
    '_parsely_visitor': '{%22id%22:%22pid=1b405088-93a3-4244-a70a-8f0b5d157233%22%2C%22session_count%22:25%2C%22last_session_ts%22:1747135330658}',
    '_lr_retry_request': 'true',
    'AMP_MKTG_c07a79acf5': 'JTdCJTdE',
    'claritas_24hrexp_ldp': 'true',
    'split_tcv': '123',
    'panoramaId_expiry': '1747223247759',
    'panoramaId': '1c8ce1f32d9b77f43d98a20754f4a9fb927a4d1c3ceb4de2702245f6f0c8d4e0',
    'ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3
MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx; KP_UIDz=0MfNNCrrSb9BV7sBp4WHRRcf76Hju6CLGwabGOT0OemzWxp7pYt891SoHjCmiqzeE4EogTl5pik6AxlNeZssOqeTyXwkGLi6ak34mTbRw8IRL3eAxozFBk7kKCJKW4DrGUsqoPvVO0Mi9LFWIIbEhrxyequ0ffzwIJVbhdPx',
}
 

location=location
# days=days
# price=price
# property_type="property_type"
final_url=final_url

url = f"https://www.realtor.com/realestateandhomes-search/{location}"

if final_url:
   url+=final_url

# if days:
#     url += f"/dom-{int(days)}"
# if price:
#     url += f"/price-{int(price)}-na"
# if property_type:
#     url += f"/type-{property_type.replace(' ', '-').lower()}"

print("🔗 Final URL:", url)
print("final url is ", final_url)

response = requests.get(
    # 'https://www.realtor.com/realestateandhomes-search/Indiana/type-multi-family-home/dom-30/price-800000-na',
    url,
    cookies=cookies,
    headers=headers,
)


link_array=[]

soup = BeautifulSoup(response.text, 'html.parser')
# print(soup.prettify())
# total_homes=soup.find('div', class_="TotalResults_totalNumber__ejYIx")
total_homes = soup.find('div', attrs={'data-testid': 'total-results'})
# script_tag = soup.find('script', {'data-testid': 'seoLinkingData', 'type': 'application/ld+json'})
script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
# print(script_tag)
# print(total_homes.text)


def get_main_entity_item_list(json_data):
    for item in json_data:
        if "mainEntity" in item:
            main_entity = item["mainEntity"]
            if "itemListElement" in main_entity:
                return main_entity["itemListElement"]
    return None  # Return None if not found

if script_tag:
  # Load the content of the script tag (it's a JSON string)
  json_data = json.loads(script_tag.string)
  # print(json_data)
  # print(json.dumps(json_data, indent=2))
  new_data=json_data["props"]["pageProps"]["properties"]
  # print(json.dumps(new_data, indent=2))
  permalinks = [item.get("permalink") for item in new_data]

print(permalinks)
link_array.append(permalinks)
# print(len(permalinks))
  # ans=json_data[1]["mainEntity"]["itemListElement"]
  # ans=get_main_entity_item_list(json_data)

  # print(json.dumps(ans,indent=2))
  # print(ans)
  # c=0
  # if (ans):
  #   for i in ans:
  #     # print(i["url"])
  #     link_array.append(i["url"])
  #     c=c+1
#   print(c)

print(total_homes.text.strip())
# Out:
# 🔗 Final URL: https://www.realtor.com/realestateandhomes-search/houston_tx/type-single-family-home/dom-1/price-500000-900000
# final url is  /type-single-family-home/dom-1/price-500000-900000
# ['2318-Hialeah-Dr_Houston_TX_77018_M85620-28183', '3726-Las-Palmas-St_Houston_TX_77027_M71570-76870', '3715-Latma-Dr_Houston_TX_77025_M83409-17974', '10328-Shadow-Oaks-Dr_Houston_TX_77043_M72255-74208', '18114-Langsbury-Dr_Houston_TX_77084_M80622-26809', '12031-Arroyo-Verde-Ln_Houston_TX_77041_M77524-43132', '14223-Stokesmount-Dr_Houston_TX_77077_M71312-08618', '1628-W-24th-St_Houston_TX_77008_M81378-66583', '1207-W-24th-St-A_Houston_TX_77008_M81607-86514', '216-W-Drew-St_Houston_TX_77006_M78706-68033', '1313-Lakin-St_Houston_TX_77007_M77427-49582', '1149-W-22nd-St_Houston_TX_77008_M84793-79936', '18407-Starlight-Valley-Trl_Cypress_TX_77433_M94672-65780', '14018-Wyndham-Terrace-Trl_Houston_TX_77059_M95637-76350', '8643-Green-Kolbe-Ln_Houston_TX_77080_M73457-51797', '13207-Terania-Cliff-Trce_Houston_TX_77059_M81677-38431', '10923-Grove-Tree-Ln_Houston_TX_77043_M91987-53248', '6003-Matthew-Oaks-Pl_Houston_TX_77007_M90979-36171', '4415-Caroline-St_Houston_TX_77004_M97271-54743', '5619-Val-Verde-St-B_Houston_TX_77057_M97996-88933', '20627-Sunny-Shores-Dr_Humble_TX_77346_M80945-47754', '2113-Emancipation-Ave_Houston_TX_77003_M94840-57500', '2103-Southwick-St_Houston_TX_77080_M85276-25850']
# 23

# %%
import math
 

if total_homes:  # Add your condition here (e.g., ensure the element exists)
    total_homes_number = int(total_homes.text.strip().replace(',', ''))

    # Now do the math
    page = math.ceil(total_homes_number / len(permalinks) )
    print("heyyyyyyyy" ,page)

    for p in range(2, page + 1):
        response = requests.get(
            f'{url}/pg-{p}',
            cookies=cookies,
            headers=headers,
        )
        print("mmmmmmmmmmmmmmmmmmmm", f'{url}/pg-{p}')
        
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            script_tag = soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
            # script_tag = soup.find('script', {'data-testid': 'seoLinkingData', 'type': 'application/ld+json'})

            

            if script_tag:
                try:
                    # Load the content of the script tag (it's a JSON string)
                    json_data = json.loads(script_tag.string)
                     
                    new_data=json_data["props"]["pageProps"]["properties"]
                    # print(json.dumps(new_data, indent=2))
                    permalinks = [item.get("permalink") for item in new_data]
                    link_array.append(permalinks)

                    # c = 0
                    # if ans:
                    #     for i in ans:
                    #         print(i["url"])
                    #         link_array.append(i["url"])
                    #         c += 1
                    print("\n\n\n\n", p)
                except Exception as e:
                    print(f"Error parsing page {p}: {e}")
# Out:
# heyyyyyyyy 1

# %%
flat_links = [link for sublist in link_array for link in sublist]
flat_links
# Out:
# ['2318-Hialeah-Dr_Houston_TX_77018_M85620-28183',
#  '3726-Las-Palmas-St_Houston_TX_77027_M71570-76870',
#  '3715-Latma-Dr_Houston_TX_77025_M83409-17974',
#  '10328-Shadow-Oaks-Dr_Houston_TX_77043_M72255-74208',
#  '18114-Langsbury-Dr_Houston_TX_77084_M80622-26809',
#  '12031-Arroyo-Verde-Ln_Houston_TX_77041_M77524-43132',
#  '14223-Stokesmount-Dr_Houston_TX_77077_M71312-08618',
#  '1628-W-24th-St_Houston_TX_77008_M81378-66583',
#  '1207-W-24th-St-A_Houston_TX_77008_M81607-86514',
#  '216-W-Drew-St_Houston_TX_77006_M78706-68033',
#  '1313-Lakin-St_Houston_TX_77007_M77427-49582',
#  '1149-W-22nd-St_Houston_TX_77008_M84793-79936',
#  '18407-Starlight-Valley-Trl_Cypress_TX_77433_M94672-65780',
#  '14018-Wyndham-Terrace-Trl_Houston_TX_77059_M95637-76350',
#  '8643-Green-Kolbe-Ln_Houston_TX_77080_M73457-51797',
#  '13207-Terania-Cliff-Trce_Houston_TX_77059_M81677-38431',
#  '10923-Grove-Tree-Ln_Houston_TX_77043_M91987-53248',
#  '6003-Matthew-Oaks-Pl_Houston_TX_77007_M90979-36171',
#  '4415-Caroline-St_Houston_TX_77004_M97271-54743',
#  '5619-Val-Verde-St-B_Houston_TX_77057_M97996-88933',
#  '20627-Sunny-Shores-Dr_Humble_TX_77346_M80945-47754',
#  '2113-Emancipation-Ave_Houston_TX_77003_M94840-57500',
#  '2103-Southwick-St_Houston_TX_77080_M85276-25850']

# %%
import requests

cookies = {
    'split': 'n',
    'split_tcv': '107',
    '__vst': '77a15ccd-e56b-4b53-84a6-dd7489460e00',
    '__bot': 'false',
    '__rdc_id': 'rdc-id-47a2b56d-5b28-4d44-b05b-5357c1cd9ff1',
    '_lr_env_src_ats': 'false',
    '__split': '99',
    's_ecid': 'MCMID%7C27884217083925427864580703870195153793',
    'permutive-id': 'dd2c92b1-9a5d-4ce0-9d63-91d6e0af362c',
    '_gcl_au': '1.1.4544760.1754888978',
    '_fbp': 'fb.1.1754888977733.551778958',
    'pbjs-unifiedid': '%7B%22TDID%22%3A%223a8d51ac-417f-4408-8582-08bc5245f811%22%2C%22TDID_LOOKUP%22%3A%22FALSE%22%2C%22TDID_CREATED_AT%22%3A%222025-08-11T05%3A09%3A36%22%7D',
    'pbjs-unifiedid_cst': 'VyxHLMwsHQ%3D%3D',
    'panoramaId_expiry': '1755493776336',
    '_cc_id': '8b1c0157cd59be4433d8d7355f0f6bb6',
    'panoramaId': '765debca47a21734d7bb1d751e44185ca02c01af0dfd853c9bda8765b5acff26',
    '__spdt': '4b9a4566ca2c445eac4fa671eb4aa49d',
    '_ga': 'GA1.1.1291459386.1754888979',
    'G_ENABLED_IDPS': 'google',
    'ajs_anonymous_id': '79bc5efb-6339-4a26-9bc2-cf97c29a73d5',
    'AMP_MKTG_c07a79acf5': 'JTdCJTdE',
    '_lr_sampling_rate': '100',
    'kampyle_userid': '8e8e-1ba3-5566-40d8-4ded-2da9-64b8-32c4',
    '_lr_retry_request': 'true',
    'ab.storage.deviceId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Aee61d111-e45f-090c-d5f2-09bf92f16946%7Ce%3Aundefined%7Cc%3A1754888977253%7Cl%3A1754993557225',
    'ab.storage.userId.7cc9d032-9d6d-44cf-a8f5-d276489af322': 'g%3Avisitor_77a15ccd-e56b-4b53-84a6-dd7489460e00%7Ce%3Aundefined%7Cc%3A1754888977248%7Cl%3A1754993557227',
    '__gsas': 'ID=9c1efb6d257cd795:T=1754993556:RT=1754993556:S=ALNI_MYngpx7clUEIOd1mUEHBfZy2vStuw',
    'claritas_24hrexp_sitevisit': 'true',
    'map_tooltip_closed': 'true',
    'kampyleUserSession': '1754993584428',
    'kampyleUserSessionsCount': '2',
    'kampyleUserPercentile': '87.62657979253888',
    '_parsely_session': '{%22sid%22:2%2C%22surl%22:%22https://www.realtor.com/realestateandhomes-search/New-York_NY/type-single-family-home/dom-1/price-600000-900000%22%2C%22sref%22:%22%22%2C%22sts%22:1754993586161%2C%22slts%22:1754889004282}',
    '_parsely_visitor': '{%22id%22:%22pid=14bd8189-5e22-4308-a6b6-003c0f19c0af%22%2C%22session_count%22:2%2C%22last_session_ts%22:1754993586161}',
    'kampyleSessionPageCounter': '2',
    '__ssn': '16b2951e-6fe9-4cc4-ad0c-1452210e4a61',
    '__ssnstarttime': '1754994175',
    'AMCVS_8853394255142B6A0A4C98A4%40AdobeOrg': '1',
    'AMCV_8853394255142B6A0A4C98A4%40AdobeOrg': '-1124106680%7CMCIDTS%7C20312%7CMCMID%7C27884217083925427864580703870195153793%7CMCAAMLH-1755598976%7C12%7CMCAAMB-1755598976%7C6G1ynYcLPuiQxYZrsz_pkqfLG9yMXBpb2zX5dvJdYQJzPXImdj0y%7CMCOPTOUT-
}

# response = requests.get(
#     'https://www.realtor.com/realestateandhomes-detail/1300-W-90th-St_Los-Angeles_CA_90044_M25280-78269',
#     cookies=cookies,
#     headers=headers,
# )
response
# Out:
# <Response [200]>

# %%
from ast import main
import requests
from bs4 import BeautifulSoup
import json
import time
import re
result=[]

 
k=1
 

if link_array:  # Add your condition here (e.g., len(link_array) > 0)
    for link in flat_links:
        # link=link+'?from=srp-list-card'
        link="https://www.realtor.com/realestateandhomes-detail/"+link
        print(link)
        detail_res = requests.get(link, cookies=cookies, headers=headers)
        k = k + 1
        print(detail_res, k)
        data = {
            "Price": "N/A",
            "Address": "N/A",
            "Realtor's Name": "N/A",
            "Realtor's Email": "N/A",
            "Realtor's Phone": "N/A",
            "Brokered Name": "N/A",
            "Estimated Price": "N/A",
            "Property Type": "N/A",
            "Days on Market": "N/A",
            "Year Built": "N/A",
            "Zip Code": "N/A",
            "Multi Listings": "N/A",
            "Link": link,
        }

        if detail_res.status_code == 200:
            # time.sleep(3)  # delay to avoid blocking
            detail_soup = BeautifulSoup(detail_res.text, 'html.parser')

            main_price = detail_soup.find("span", class_="base__StyledType-rui__sc-18muj27-0 idlIli")
            
            if main_price:
                data['Price'] = main_price.text.strip()

            main_address = detail_soup.find("h1", class_="sc-fa97e35a-3 dgxOov")
            
            if main_address:
                data['Address'] = main_address.text.strip()

            script_tag = detail_soup.find('script', {'id': '__NEXT_DATA__', 'type': 'application/json'})
            if script_tag:
                try:
                    json_data = json.loads(script_tag.string)
                    advertiser_info = json_data["props"]["pageProps"]["initialReduxState"]["propertyDetails"]["advertisers"][0]

                    data["Realtor's Name"] = advertiser_info.get("name", "N/A")
                    data["Realtor's Email"] = advertiser_info.get("email", "N/A")
                    data["Realtor's Phone"] = advertiser_info["phones"][0].get("number", "N/A")
                    data["Brokered Name"] = advertiser_info["office"].get("name")
                    data["Estimated Price"] = json_data["props"]["pageProps"]["initialReduxState"]["propertyDetails"].get("estimate", {}).get("price", "N/A")
                    data["Zip Code"] = re.search(r'\b\d{5}\b', detail_soup.text).group() if re.search(r'\b\d{5}\b', detail_soup.text) else "N/A"
                except Exception as e:
                    data["error"] = str(e)

            # multi_listings = detail_soup.find("div", class_="sc-205c724c-0 ficrCd")
            # if multi_listings:
            #     listings = multi_listings.find_all('a')
            #     data["Multi Listings"] = len(listings)

            multi_listings = detail_soup.find("div", class_="sc-205c724c-0 ficrCd")
            if multi_listings:
                listings = multi_listings.find_all('a')
                data["Multi Listings"] = str(len(listings))   
            else:
                data["Multi Listings"] = "0"   

 

            fifi = detail_soup.find("ul", "sc-596aad4c-0 fdDkrT")
            if fifi:
                prop_type_tag = fifi.find('span', string="Property type")
                data["Property Type"] = prop_type_tag.find_next('p').text.strip() if prop_type_tag else "N/A"

                # dom_tag = fifi.find('span', string="On Realtor.com")
                # data["Days on Market"] = dom_tag.find_next('p').text.strip() if dom_tag else "N/A"
                dom_tag = fifi.find('p', class_="base__StyledType-rui__sc-18muj27-0 bNJOGz sc-c1d03842-3 cCvGvj")
                data["Days on Market"] = dom_tag.find_next('p').text.strip() if dom_tag else "N/A"

                year_built_tag = fifi.find('span', string="Year built")
                data["Year Built"] = year_built_tag.find_next('p').text.strip() if year_built_tag else "N/A"

            estim = detail_soup.find("div", "mortgage-components-bx9k35 jhJBqN")
            if estim:
                price = estim.find('span', class_='base__StyledType-rui__sc-18muj27-0 idlIli')
                
                if price:
                    data["Estimated Price"] = price.text.strip()

        result.append(data)

else:
    result.append({'message': 'No property URLs found.'})
# Out:
# https://www.realtor.com/realestateandhomes-detail/2318-Hialeah-Dr_Houston_TX_77018_M85620-28183
# <Response [200]> 2
# https://www.realtor.com/realestateandhomes-detail/3726-Las-Palmas-St_Houston_TX_77027_M71570-76870
# <Response [200]> 3
# https://www.realtor.com/realestateandhomes-detail/3715-Latma-Dr_Houston_TX_77025_M83409-17974
# <Response [200]> 4
# https://www.realtor.com/realestateandhomes-detail/10328-Shadow-Oaks-Dr_Houston_TX_77043_M72255-74208
# <Response [200]> 5
# https://www.realtor.com/realestateandhomes-detail/18114-Langsbury-Dr_Houston_TX_77084_M80622-26809
# <Response [200]> 6
# https://www.realtor.com/realestateandhomes-detail/12031-Arroyo-Verde-Ln_Houston_TX_77041_M77524-43132
# <Response [200]> 7
# https://www.realtor.com/realestateandhomes-detail/14223-Stokesmount-Dr_Houston_TX_77077_M71312-08618
# <Response [200]> 8
# https://www.realtor.com/realestateandhomes-detail/1628-W-24th-St_Houston_TX_77008_M81378-66583
# <Response [200]> 9
# https://www.realtor.com/realestateandhomes-detail/1207-W-24th-St-A_Houston_TX_77008_M81607-86514
# <Response [200]> 10
# https://www.realtor.com/realestateandhomes-detail/216-W-Drew-St_Houston_TX_77006_M78706-68033
# <Response [200]> 11
# https://www.realtor.com/realestateandhomes-detail/1313-Lakin-St_Houston_TX_77007_M77427-49582
# <Response [200]> 12
# https://www.realtor.com/realestateandhomes-detail/1149-W-22nd-St_Houston_TX_77008_M84793-79936
# <Response [200]> 13
# https://www.realtor.com/realestateandhomes-detail/18407-Starlight-Valley-Trl_Cypress_TX_77433_M94672-65780
# <Response [200]> 14
# https://www.realtor.com/realestateandhomes-detail/14018-Wyndham-Terrace-Trl_Houston_TX_77059_M95637-76350
# <Response [200]> 15
# https://www.realtor.com/realestateandhomes-detail/8643-Green-Kolbe-Ln_Houston_TX_77080_M73457-51797
# <Response [200]> 16
# https://www.realtor.com/realestateandhomes-detail/13207-Terania-Cliff-Trce_Houston_TX_77059_M81677-38431
# <Response [200]> 17
# https://www.realtor.com/realestateandhomes-detail/10923-Grove-Tree-Ln_Houston_TX_77043_M91987-53248
# <Response [200]> 18
# https://www.realtor.com/realestateandhomes-detail/6003-Matthew-Oaks-Pl_Houston_TX_77007_M90979-36171
# <Response [200]> 19
# https://www.realtor.com/realestateandhomes-detail/4415-Caroline-St_Houston_TX_77004_M97271-54743
# <Response [200]> 20
# https://www.realtor.com/realestateandhomes-detail/5619-Val-Verde-St-B_Houston_TX_77057_M97996-88933
# <Response [200]> 21
# https://www.realtor.com/realestateandhomes-detail/20627-Sunny-Shores-Dr_Humble_TX_77346_M80945-47754
# <Response [200]> 22
# https://www.realtor.com/realestateandhomes-detail/2113-Emancipation-Ave_Houston_TX_77003_M94840-57500
# <Response [200]> 23
# https://www.realtor.com/realestateandhomes-detail/2103-Southwick-St_Houston_TX_77080_M85276-25850
# <Response [200]> 24

# %%
print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "Price": "$650,000",
#     "Address": "2318 Hialeah Dr, Houston, TX 77018",
#     "Realtor's Name": "JOHN PRELL, Broker",
#     "Realtor's Email": "listing@creekviewrealty.com",
#     "Realtor's Phone": "2146964663",
#     "Brokered Name": "Creekview Realty",
#     "Estimated Price": "$4,496",
#     "Property Type": "Single family",
#     "Days on Market": "18 hours",
#     "Year Built": "1954",
#     "Zip Code": "77018",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2318-Hialeah-Dr_Houston_TX_77018_M85620-28183"
#   },
#   {
#     "Price": "$750,000",
#     "Address": "3726 Las Palmas St, Houston, TX 77027",
#     "Realtor's Name": "Marnie Greenwood",
#     "Realtor's Email": "marnie@marnierocks.com",
#     "Realtor's Phone": "(713) 416-8402",
#     "Brokered Name": "Compass RE Texas LLC - Westheimer",
#     "Estimated Price": "$5,398",
#     "Property Type": "Single family",
#     "Days on Market": "17 hours",
#     "Year Built": "1950",
#     "Zip Code": "77027",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3726-Las-Palmas-St_Houston_TX_77027_M71570-76870"
#   },
#   {
#     "Price": "$549,000",
#     "Address": "3715 Latma Dr, Houston, TX 77025",
#     "Realtor's Name": "Jacob George",
#     "Realtor's Email": "jacobgeorgejr@gmail.com",
#     "Realtor's Phone": "(281) 796-0143",
#     "Brokered Name": "Texas Signature Realty",
#     "Estimated Price": "$4,010",
#     "Property Type": "Single family",
#     "Days on Market": "12 hours",
#     "Year Built": "1958",
#     "Zip Code": "77025",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/3715-Latma-Dr_Houston_TX_77025_M83409-17974"
#   },
#   {
#     "Price": "$599,000",
#     "Address": "10328 Shadow Oaks Dr, Houston, TX 77043",
#     "Realtor's Name": "Marie Gilbert",
#     "Realtor's Email": "mariegilbert@remax.net",
#     "Realtor's Phone": "2812366640",
#     "Brokered Name": "RE MAX Signature",
#     "Estimated Price": "$4,472",
#     "Property Type": "Single family",
#     "Days on Market": "12 hours",
#     "Year Built": "1956",
#     "Zip Code": "10328",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/10328-Shadow-Oaks-Dr_Houston_TX_77043_M72255-74208"
#   },
#   {
#     "Price": "$609,000",
#     "Address": "18114 Langsbury Dr, Houston, TX 77084",
#     "Realtor's Name": "Eric Cuevas",
#     "Realtor's Email": "ecuevas@remax.net",
#     "Realtor's Phone": "7133011560",
#     "Brokered Name": "RE MAX Compass",
#     "Estimated Price": "$4,470",
#     "Property Type": "Single family",
#     "Days on Market": "12 hours",
#     "Year Built": "1994",
#     "Zip Code": "18114",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/18114-Langsbury-Dr_Houston_TX_77084_M80622-26809"
#   },
#   {
#     "Price": "$675,000",
#     "Address": "12031 Arroyo Verde Ln, Houston, TX 77041",
#     "Realtor's Name": "Kendra Larson",
#     "Realtor's Email": "",
#     "Realtor's Phone": "2819611437",
#     "Brokered Name": "Exp Realty LLC",
#     "Estimated Price": "$5,273",
#     "Property Type": "Single family",
#     "Days on Market": "17 hours",
#     "Year Built": "2000",
#     "Zip Code": "12031",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/12031-Arroyo-Verde-Ln_Houston_TX_77041_M77524-43132"
#   },
#   {
#     "Price": "$550,000",
#     "Address": "14223 Stokesmount Dr, Houston, TX 77077",
#     "Realtor's Name": "Shah M. Haleem",
#     "Realtor's Email": "countonshah@yahoo.com",
#     "Realtor's Phone": "(281) 748-9880",
#     "Brokered Name": "Realm Real Estate Professional",
#     "Estimated Price": "$3,676",
#     "Property Type": "Single family",
#     "Days on Market": "14 hours",
#     "Year Built": "1980",
#     "Zip Code": "14223",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/14223-Stokesmount-Dr_Houston_TX_77077_M71312-08618"
#   },
#   {
#     "Price": "$537,500",
#     "Address": "1628 W 24th St, Houston, TX 77008",
#     "Realtor's Name": "James Krueger",
#     "Realtor's Email": "james@corcoranprestige.com",
#     "Realtor's Phone": "7133644003",
#     "Brokered Name": "Corcoran Prestige Realty",
#     "Estimated Price": "$4,106",
#     "Property Type": "Single family",
#     "Days on Market": "18 hours",
#     "Year Built": "2016",
#     "Zip Code": "77008",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1628-W-24th-St_Houston_TX_77008_M81378-66583"
#   },
#   {
#     "Price": "$520,000",
#     "Address": "1207 W 24th St Unit A, Houston, TX 77008",
#     "Realtor's Name": "Katherine Cancelmo",
#     "Realtor's Email": "",
#     "Realtor's Phone": "7139073883",
#     "Brokered Name": "GREENWOOD KING PROPERTIES",
#     "Estimated Price": "$3,958",
#     "Property Type": "Single family",
#     "Days on Market": "14 hours",
#     "Year Built": "2016",
#     "Zip Code": "77008",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1207-W-24th-St-A_Houston_TX_77008_M81607-86514"
#   },
#   {
#     "Price": "$830,000",
#     "Address": "216 W Drew St, Houston, TX 77006",
#     "Realtor's Name": "Walter Bering",
#     "Realtor's Email": "Walter.Bering@Sothebys.Realty",
#     "Realtor's Phone": "7135583232",
#     "Brokered Name": "Martha Turner Sotheby's International Realty - Central Houston Brokerage",
#     "Estimated Price": "$6,093",
#     "Property Type": "Single family",
#     "Days on Market": "12 hours",
#     "Year Built": "2015",
#     "Zip Code": "77006",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/216-W-Drew-St_Houston_TX_77006_M78706-68033"
#   },
#   {
#     "Price": "$675,000",
#     "Address": "1313 Lakin St, Houston, TX 77007",
#     "Realtor's Name": "Monica Overstreet",
#     "Realtor's Email": "monica.overstreet@cbunited.com",
#     "Realtor's Phone": "7132487968",
#     "Brokered Name": "Berkshire Hathaway HomeServices Premier Properties",
#     "Estimated Price": "$4,942",
#     "Property Type": "Single family",
#     "Days on Market": "22 hours",
#     "Year Built": "2018",
#     "Zip Code": "77007",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1313-Lakin-St_Houston_TX_77007_M77427-49582"
#   },
#   {
#     "Price": "$629,900",
#     "Address": "1149 W 22nd St, Houston, TX 77008",
#     "Realtor's Name": "Demetrice Ballenger",
#     "Realtor's Email": "demetrice@cqhouston.com",
#     "Realtor's Phone": "7135855626",
#     "Brokered Name": "Wynnwood Group",
#     "Estimated Price": "$3,819",
#     "Property Type": "Single family",
#     "Days on Market": "11 hours",
#     "Year Built": "2025",
#     "Zip Code": "77008",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/1149-W-22nd-St_Houston_TX_77008_M84793-79936"
#   },
#   {
#     "Price": "$599,000",
#     "Address": "18407 Starlight Valley Trl, Cypress, TX 77433",
#     "Realtor's Name": "Jiamin Chen",
#     "Realtor's Email": "houston.realestate.channels@gmail.com",
#     "Realtor's Phone": "(346) 331-1389",
#     "Brokered Name": "First Us Services&Channels LLC",
#     "Estimated Price": "$3,814",
#     "Property Type": "Single family",
#     "Days on Market": "1 day",
#     "Year Built": "2024",
#     "Zip Code": "18407",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/18407-Starlight-Valley-Trl_Cypress_TX_77433_M94672-65780"
#   },
#   {
#     "Price": "$675,000",
#     "Address": "14018 Wyndham Terrace Trl, Houston, TX 77059",
#     "Realtor's Name": "Lisa Smith",
#     "Realtor's Email": "",
#     "Realtor's Phone": "2816354007",
#     "Brokered Name": "Better Homes and Gardens Real Estate Gary Greene - Bay Area",
#     "Estimated Price": "$5,564",
#     "Property Type": "Single family",
#     "Days on Market": "18 hours",
#     "Year Built": "2020",
#     "Zip Code": "14018",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/14018-Wyndham-Terrace-Trl_Houston_TX_77059_M95637-76350"
#   },
#   {
#     "Price": "$602,500",
#     "Address": "8643 Green Kolbe Ln, Houston, TX 77080",
#     "Realtor's Name": "Ann Kraase",
#     "Realtor's Email": "ann@kraasepropertygroup.com",
#     "Realtor's Phone": "2819616588",
#     "Brokered Name": "Keller Williams Memorial",
#     "Estimated Price": "$4,749",
#     "Property Type": "Single family",
#     "Days on Market": "19 hours",
#     "Year Built": "2017",
#     "Zip Code": "77080",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/8643-Green-Kolbe-Ln_Houston_TX_77080_M73457-51797"
#   },
#   {
#     "Price": "$625,000",
#     "Address": "13207 Terania Cliff Trce, Houston, TX 77059",
#     "Realtor's Name": "Eric Chiang",
#     "Realtor's Email": "",
#     "Realtor's Phone": "8322083265",
#     "Brokered Name": "Winhill Advisors - Kirby",
#     "Estimated Price": "$4,942",
#     "Property Type": "Single family",
#     "Days on Market": "14 hours",
#     "Year Built": "2018",
#     "Zip Code": "13207",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/13207-Terania-Cliff-Trce_Houston_TX_77059_M81677-38431"
#   },
#   {
#     "Price": "$525,000",
#     "Address": "10923 Grove Tree Ln, Houston, TX 77043",
#     "Realtor's Name": "Joe Zamora",
#     "Realtor's Email": "zamora_joe@msn.com",
#     "Realtor's Phone": "(713) 440-7416",
#     "Brokered Name": "Keller Williams Realty Metropolitan",
#     "Estimated Price": "$4,057",
#     "Property Type": "Single family",
#     "Days on Market": "14 hours",
#     "Year Built": "2019",
#     "Zip Code": "10923",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/10923-Grove-Tree-Ln_Houston_TX_77043_M91987-53248"
#   },
#   {
#     "Price": "$779,000",
#     "Address": "6003 Matthew Oaks Pl, Houston, TX 77007",
#     "Realtor's Name": "Rene Sorola",
#     "Realtor's Email": "rene@renesorola.com",
#     "Realtor's Phone": "8325885842",
#     "Brokered Name": "Keller Williams Realty Metropolitan",
#     "Estimated Price": "$6,008",
#     "Property Type": "Single family",
#     "Days on Market": "13 hours",
#     "Year Built": "2019",
#     "Zip Code": "77007",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/6003-Matthew-Oaks-Pl_Houston_TX_77007_M90979-36171"
#   },
#   {
#     "Price": "$599,000",
#     "Address": "4415 Caroline St, Houston, TX 77004",
#     "Realtor's Name": "Destiny Demuren",
#     "Realtor's Email": "",
#     "Realtor's Phone": "N/A",
#     "Brokered Name": "N/A",
#     "Estimated Price": "$3,760",
#     "Property Type": "Single family",
#     "Days on Market": "17 hours",
#     "Year Built": "2025",
#     "Zip Code": "N/A",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/4415-Caroline-St_Houston_TX_77004_M97271-54743",
#     "error": "'NoneType' object is not subscriptable"
#   },
#   {
#     "Price": "$650,000",
#     "Address": "5619 Val Verde St Unit B, Houston, TX 77057",
#     "Realtor's Name": "Phoebe Nguyen",
#     "Realtor's Email": "",
#     "Realtor's Phone": "7139093777",
#     "Brokered Name": "Exp Realty LLC",
#     "Estimated Price": "$4,341",
#     "Property Type": "Single family",
#     "Days on Market": "11 hours",
#     "Year Built": "2025",
#     "Zip Code": "77057",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/5619-Val-Verde-St-B_Houston_TX_77057_M97996-88933"
#   },
#   {
#     "Price": "$579,000",
#     "Address": "20627 Sunny Shores Dr, Houston, TX 77346",
#     "Realtor's Name": "Julia Owens",
#     "Realtor's Email": "juliaowens@kw.com",
#     "Realtor's Phone": "8325141222",
#     "Brokered Name": "Keller Williams Elite",
#     "Estimated Price": "$3,528",
#     "Property Type": "Single family",
#     "Days on Market": "14 hours",
#     "Year Built": "2025",
#     "Zip Code": "20627",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/20627-Sunny-Shores-Dr_Humble_TX_77346_M80945-47754"
#   },
#   {
#     "Price": "$529,000",
#     "Address": "2113 Emancipation Ave, Houston, TX 77003",
#     "Realtor's Name": "Ashwin Kewalramani",
#     "Realtor's Email": "",
#     "Realtor's Phone": "(713) 373-7401",
#     "Brokered Name": "New Age",
#     "Estimated Price": "$3,421",
#     "Property Type": "Single family",
#     "Days on Market": "7 hours",
#     "Year Built": "2025",
#     "Zip Code": "77003",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2113-Emancipation-Ave_Houston_TX_77003_M94840-57500"
#   },
#   {
#     "Price": "$699,000",
#     "Address": "2103 Southwick St, Houston, TX 77080",
#     "Realtor's Name": "Nikki Goins",
#     "Realtor's Email": "",
#     "Realtor's Phone": "7133578570",
#     "Brokered Name": "Keller Williams Hou Preferred",
#     "Estimated Price": "$4,858",
#     "Property Type": "Single family",
#     "Days on Market": "16 hours",
#     "Year Built": "1962",
#     "Zip Code": "77080",
#     "Multi Listings": "0",
#     "Link": "https://www.realtor.com/realestateandhomes-detail/2103-Southwick-St_Houston_TX_77080_M85276-25850"
#   }
# ]
